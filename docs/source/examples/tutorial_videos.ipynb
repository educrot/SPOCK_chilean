# %% [markdown]
# # Tutorial videos

# %% [markdown]
# ## Using Python script

# %% [markdown]
# <video width="700" controls src="./test2.mov" />

# %% [markdown]
# ## Using the `spock_chilean` app

# %% [markdown]
# <video width="700" controls src="./test.mov" />
