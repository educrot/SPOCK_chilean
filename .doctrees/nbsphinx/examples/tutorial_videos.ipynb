# %% [markdown]
# # Tutorial videos

# %% [markdown]
# ## Installation

# %%
from IPython.display import HTML
import warnings
warnings.filterwarnings('ignore')

# Youtube
HTML('<iframe width="700" height="400" src="https://www.youtube.com/embed/iOy4-5JCQ1U" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="700" height="400" src="https://www.youtube.com/embed/iOy4-5JCQ1U" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# ## Using the `spock_chilean` app

# %%
# Youtube
HTML('<iframe width="700" height="400" src="https://www.youtube.com/embed/ggXLqh9oNgw" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="700" height="400" src="https://www.youtube.com/embed/ggXLqh9oNgw" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# ## Using  a script to run `spock_chilean`

# %%
# Youtube
HTML('<iframe width="700" height="400" src="https://www.youtube.com/embed/E2g0w1N0vtU" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="700" height="400" src="https://www.youtube.com/embed/E2g0w1N0vtU" frameborder="0" allowfullscreen></iframe>
